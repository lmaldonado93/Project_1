# 403  403       112      43  Female     White   43  2019        2
# 404  404       113      44    Male     Asian   61  2019        2
#
# [405 rows x 8 columns]

# %%
# Show mulitple specific columns required for this project by Gender, Race, precinct and Age

HATECRIME = Hatecrime[["Precinct", "Gender", "Race", "Age"]]
HATECRIME
# Out:
#      Precinct  Gender      Race  Age
# 0           6    Male  Hispanic   48
# 1           7    Male     White   29
# 2           7    Male     White   29
# 3          14    Male  Hispanic   64
# 4          14    Male  Hispanic   64
# 5          14    Male  Hispanic   64
# 6          14    Male  Hispanic   64
# 7          14    Male  Hispanic   64
# 8          14    Male  Hispanic   64
# 9          14    Male  Hispanic   64
# 10         14    Male  Hispanic   64
# 11         14    Male     White   26
# 12         14    Male     White   28
# 13         19    Male     White   53
# 14         20    Male  Hispanic   22
# 15         22    Male     White   33
# 16         52    Male     Black   40
# 17         61    Male     White   25
# 18         61    Male     Black   16
# 19         71    Male     Black   11
# 20         71    Male     Black   11
# 21         75    Male     Black   28
# 22         79    Male     Black   32
# 23         79    Male     Black   32
# 24         84    Male     White   36
# 25         88    Male  Hispanic   60
# 26         94    Male  Hispanic   32
# 27        107    Male  Hispanic   28
# 28        113    Male     White   57
# 29        115    Male  Hispanic   38
# ..        ...     ...       ...  ...
# 375        42  Female     White   15
# 376        61    Male     White   55
# 377        61    Male     White   55
# 378        68    Male     White   21
# 379        70    Male     White   41
# 380        70    Male     White   34
# 381        71  Female     Black   52
# 382        75    Male     White   46
# 383        75    Male     White   46
# 384        75    Male     White   37
# 385        81    Male     Black   26
# 386        84    Male     White   48
# 387        88    Male     White   47
# 388        90    Male     Black   16
# 389        94    Male     White   28
# 390        94    Male     White   28
# 391        94    Male     White   28
# 392        94    Male     White   28
# 393        94    Male     White   28
# 394        94    Male     White   28
# 395        94    Male     White   28
# 396        94    Male     White   28
# 397       101    Male     Black   14
# 398       102    Male     Asian   37
# 399       103    Male     White   55
# 400       107  Female     Asian   23
# 401       107    Male     Asian   21
# 402       110  Female     White   24
# 403       112  Female     White   43
# 404       113    Male     Asian   61
#
# [405 rows x 4 columns]

# %%
HATECRIME.columns
# Out:
# Index(['Precinct', 'Gender', 'Race', 'Age'], dtype='object')

# %%
HATECRIME["Race"].value_counts()
# Out:
# White       202
# Black       153
# Hispanic     27
# Asian        19
# Unknown       4
# Name: Race, dtype: int64

# %%
HATECRIME["Gender"].value_counts()
# Out:
# Male      361
# Female     44
# Name: Gender, dtype: int64

# %%
HATECRIME["Precinct"].value_counts()
# Out:
# 71     25
# 61     18
# 94     17
# 18     16
# 14     16
# 90     15
# 84     12
# 75     12
# 120    11
# 79     10
# 1      10
# 70     10
# 66      9
# 9       8
# 110     8
# 112     8
# 7       8
# 23      7
# 60      7
# 34      7
# 81      7
# 107     7
# 6       7
# 17      6
# 20      6
# 83      6
# 28      5
# 13      5
# 33      5
# 115     5
#        ..
# 26      3
# 25      3
# 10      3
# 19      3
# 63      3
# 104     3
# 102     3
# 52      3
# 62      3
# 122     3
# 77      3
# 108     3
# 73      2
# 41      2
# 88      2
# 78      2
# 106     2
# 111     2
# 72      2
# 67      2
# 32      2
# 50      2
# 109     1
# 121     1
# 46      1
# 22      1
# 101     1
# 76      1
# 49      1
# 123     1
# Name: Precinct, Length: 72, dtype: int64

# %%
# segmenting the age into different group 
#define bins as 10 to 19, 19-29, 29-39, 39-49, 49-59, 59-69,69-79,79-89
bins = [10, 19, 29, 39, 49, 59, 69, 79, 89]

# %%
group_names = ["denarian(10-19)", "vicenarian(20-29)", "tricenarian(30-39)", "quadragenarian(40-49)", "quinquagenarian(50-59)", "sexagenarian(60-69)", "septuagenarian(70-79)", "octogenarian(80-89)"]

# %%
HATECRIME["Age bracket"] = pd.cut(HATECRIME["Age"], bins, labels=group_names)
HATECRIME["Age bracket"].value_counts()
# Out:
# C:\Users\molayink\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# vicenarian(20-29)         134
# tricenarian(30-39)        109
# denarian(10-19)            60
# quadragenarian(40-49)      47
# quinquagenarian(50-59)     36
# sexagenarian(60-69)        15
# septuagenarian(70-79)       4
# octogenarian(80-89)         0
# Name: Age bracket, dtype: int64

# %%
HATECRIME.columns
# Out:
# Index(['Precinct', 'Gender', 'Race', 'Age', 'Age bracket'], dtype='object')

# %%
# dataframe changed from hatecrime to HATECRIME after age segmentation
HATECRIME
# Out:
#      Precinct  Gender      Race  Age             Age bracket
# 0           6    Male  Hispanic   48   quadragenarian(40-49)
# 1           7    Male     White   29       vicenarian(20-29)
# 2           7    Male     White   29       vicenarian(20-29)
# 3          14    Male  Hispanic   64     sexagenarian(60-69)
# 4          14    Male  Hispanic   64     sexagenarian(60-69)
# 5          14    Male  Hispanic   64     sexagenarian(60-69)
# 6          14    Male  Hispanic   64     sexagenarian(60-69)
# 7          14    Male  Hispanic   64     sexagenarian(60-69)
# 8          14    Male  Hispanic   64     sexagenarian(60-69)
# 9          14    Male  Hispanic   64     sexagenarian(60-69)
# 10         14    Male  Hispanic   64     sexagenarian(60-69)
# 11         14    Male     White   26       vicenarian(20-29)
# 12         14    Male     White   28       vicenarian(20-29)
# 13         19    Male     White   53  quinquagenarian(50-59)
# 14         20    Male  Hispanic   22       vicenarian(20-29)
# 15         22    Male     White   33      tricenarian(30-39)
# 16         52    Male     Black   40   quadragenarian(40-49)
# 17         61    Male     White   25       vicenarian(20-29)
# 18         61    Male     Black   16         denarian(10-19)
# 19         71    Male     Black   11         denarian(10-19)
# 20         71    Male     Black   11         denarian(10-19)
# 21         75    Male     Black   28       vicenarian(20-29)
# 22         79    Male     Black   32      tricenarian(30-39)
# 23         79    Male     Black   32      tricenarian(30-39)
# 24         84    Male     White   36      tricenarian(30-39)
# 25         88    Male  Hispanic   60     sexagenarian(60-69)
# 26         94    Male  Hispanic   32      tricenarian(30-39)
# 27        107    Male  Hispanic   28       vicenarian(20-29)
# 28        113    Male     White   57  quinquagenarian(50-59)
# 29        115    Male  Hispanic   38      tricenarian(30-39)
# ..        ...     ...       ...  ...                     ...
# 375        42  Female     White   15         denarian(10-19)
# 376        61    Male     White   55  quinquagenarian(50-59)
# 377        61    Male     White   55  quinquagenarian(50-59)
# 378        68    Male     White   21       vicenarian(20-29)
# 379        70    Male     White   41   quadragenarian(40-49)
# 380        70    Male     White   34      tricenarian(30-39)
# 381        71  Female     Black   52  quinquagenarian(50-59)
# 382        75    Male     White   46   quadragenarian(40-49)
# 383        75    Male     White   46   quadragenarian(40-49)
# 384        75    Male     White   37      tricenarian(30-39)
# 385        81    Male     Black   26       vicenarian(20-29)
# 386        84    Male     White   48   quadragenarian(40-49)
# 387        88    Male     White   47   quadragenarian(40-49)
# 388        90    Male     Black   16         denarian(10-19)
# 389        94    Male     White   28       vicenarian(20-29)
# 390        94    Male     White   28       vicenarian(20-29)
# 391        94    Male     White   28       vicenarian(20-29)
# 392        94    Male     White   28       vicenarian(20-29)
# 393        94    Male     White   28       vicenarian(20-29)
# 394        94    Male     White   28       vicenarian(20-29)
# 395        94    Male     White   28       vicenarian(20-29)
# 396        94    Male     White   28       vicenarian(20-29)
# 397       101    Male     Black   14         denarian(10-19)
# 398       102    Male     Asian   37      tricenarian(30-39)
# 399       103    Male     White   55  quinquagenarian(50-59)
# 400       107  Female     Asian   23       vicenarian(20-29)
# 401       107    Male     Asian   21       vicenarian(20-29)
# 402       110  Female     White   24       vicenarian(20-29)
# 403       112  Female     White   43   quadragenarian(40-49)
# 404       113    Male     Asian   61     sexagenarian(60-69)
#
# [405 rows x 5 columns]

# %%
#percentage of male and female hate crime from 2017-2019

HATECRIME["Gender"].value_counts().plot.pie(subplots=True, figsize=(10, 8), autopct="%1.1f%%")
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x000000002E72B6D8>],
#       dtype=object)

# %%
#percentage of Race that commited hate crime for the whole data from 2017-2019
HATECRIME["Race"].value_counts().plot.pie(subplots=True, figsize=(10, 8), autopct="%1.1f%%")
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x00000000268182B0>],
#       dtype=object)

# %%
# Age segment percentage of the people committed hate crime
HATECRIME["Age bracket"].value_counts().plot.pie(subplots=True, figsize=(10, 8), autopct="%1.1f%%")
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x0000000030BA0A90>],
#       dtype=object)

# %%
#FB1 Offender's Race, Ethnicity, and Age in 2017....Showing FBI data to compare later with NY

# %%
# Store filepath in a variable
FBI_hatecrime = "../Resources/FB1 Offender's Race, Ethnicity, and Age, 2017.csv"

# %%
FBI_hatecrime = pd.read_csv("C:/Users/molayink/07-Project-1/Resources/FB1 Offender's Race, Ethnicity, and Age, 2017.csv")
FBI_hatecrime
# Out:
#                            Race/Ethnicity/Age  Total
# 0                                        Race  6,370
# 1                                       White  3,227
# 2                   Black or African American  1,359
# 3            American Indian or Alaska Native     49
# 4                                       Asian     42
# 5   Native Hawaiian or Other Pacific Islander      3
# 6                    Group of Multiple Races2    475
# 7                                Unknown Race  1,215
# 8                                 Ethnicity3   5,131
# 9                          Hispanic or Latino    454
# 10                     Not Hispanic or Latino  1,284
# 11             Group of Multiple Ethnicities4     81
# 12                          Unknown Ethnicity  3,312
# 13                                       Age3  4,895
# 14          Total known offenders 18 and over  4,062
# 15             Total known offenders under 18    833
# 16                                        NaN    NaN
# 17                                        NaN    NaN
# 18                                        NaN    NaN
# 19                                        NaN    NaN
# 20                                        NaN    NaN
# 21                                               NaN

# %%
FBI_hatecrime.columns
# Out:
# Index(['Race/Ethnicity/Age', 'Total'], dtype='object')

# %%
FBI_HATECRIME = FBI_hatecrime.rename(columns={"Race/Ethnicity/Age":"Hatecrime"})                      
                       
FBI_HATECRIME
# Out:
#                                     Hatecrime  Total
# 0                                        Race  6,370
# 1                                       White  3,227
# 2                   Black or African American  1,359
# 3            American Indian or Alaska Native     49
# 4                                       Asian     42
# 5   Native Hawaiian or Other Pacific Islander      3
# 6                    Group of Multiple Races2    475
# 7                                Unknown Race  1,215
# 8                                 Ethnicity3   5,131
# 9                          Hispanic or Latino    454
# 10                     Not Hispanic or Latino  1,284
# 11             Group of Multiple Ethnicities4     81
# 12                          Unknown Ethnicity  3,312
# 13                                       Age3  4,895
# 14          Total known offenders 18 and over  4,062
# 15             Total known offenders under 18    833
# 16                                        NaN    NaN
# 17                                        NaN    NaN
# 18                                        NaN    NaN
# 19                                        NaN    NaN
# 20                                        NaN    NaN
# 21                                               NaN

# %%
FBI_HATECRIME_FORMATED = FBI_HATECRIME.dropna()
FBI_HATECRIME_FORMATED
# Out:
#                                     Hatecrime  Total
# 0                                        Race  6,370
# 1                                       White  3,227
# 2                   Black or African American  1,359
# 3            American Indian or Alaska Native     49
# 4                                       Asian     42
# 5   Native Hawaiian or Other Pacific Islander      3
# 6                    Group of Multiple Races2    475
# 7                                Unknown Race  1,215
# 8                                 Ethnicity3   5,131
# 9                          Hispanic or Latino    454
# 10                     Not Hispanic or Latino  1,284
# 11             Group of Multiple Ethnicities4     81
# 12                          Unknown Ethnicity  3,312
# 13                                       Age3  4,895
# 14          Total known offenders 18 and over  4,062
# 15             Total known offenders under 18    833

# %%
RACE = FBI_HATECRIME_FORMATED.iloc[1:8]
RACE
# Out:
#                                    Hatecrime  Total
# 1                                      White  3,227
# 2                  Black or African American  1,359
# 3           American Indian or Alaska Native     49
# 4                                      Asian     42
# 5  Native Hawaiian or Other Pacific Islander      3
# 6                   Group of Multiple Races2    475
# 7                               Unknown Race  1,215

# %%
RACE.groupby("Hatecrime")["Total"].value_counts()
# Out:
# Hatecrime                                  Total
# American Indian or Alaska Native           49       1
# Asian                                      42       1
# Black or African American                  1,359    1
# Group of Multiple Races2                   475      1
# Native Hawaiian or Other Pacific Islander  3        1
# Unknown Race                               1,215    1
# White                                      3,227    1
# Name: Total, dtype: int64

# %%
# Labels for the sections of our pie chart
labels = ["American Indian or Alaska Native ", "Asian", "Black or African American", "Group of Multiple Races2", "Native Hawaiian", "Unknown Race", "White"]

# The values of each section of the pie chart
sizes = [49, 42, 1359, 475, 3, 1215, 3227]

# The colors of each section of the pie chart
colors = ["red", "orange", "lightcoral", "lightskyblue", "black", "blue", "green"]

# Tells matplotlib to seperate the "Python" section from the others
explode = (0.1, 0, 0, 0)

# %%
# Creates the pie chart based upon the values above
# Automatically finds the percentages of each part of the pie chart
plt.pie(sizes, labels=labels, colors=colors,
        autopct="%1.1f%%", shadow=True, startangle=140)
# Out:
# ([<matplotlib.patches.Wedge at 0x30dd2198>,
#   <matplotlib.patches.Wedge at 0x30dd2b38>,
#   <matplotlib.patches.Wedge at 0x30ddd4a8>,
#   <matplotlib.patches.Wedge at 0x30ddddd8>,
#   <matplotlib.patches.Wedge at 0x30de8748>,
#   <matplotlib.patches.Wedge at 0x30df70b8>,
#   <matplotlib.patches.Wedge at 0x30df79e8>],
#  [Text(-0.8594882174814044, 0.686498364171859, 'American Indian or Alaska Native '),
#   Text(-0.8894224028446733, 0.6472463127110172, 'Asian'),
#   Text(-1.0978955049154413, -0.06801073655290131, 'Black or African American'),
#   Text(-0.625119243883086, -0.9051110047541345, 'Group of Multiple Races2'),
#   Text(-0.3964266797650233, -1.02608278787361, 'Native Hawaiian'),
#   Text(0.252934421703941, -1.070525188081669, 'Unknown Race'),
#   Text(0.7243679374204964, 0.8278231038314744, 'White')],
#  [Text(-0.4688117549898569, 0.37445365318465035, '0.8%'),
#   Text(-0.48513949246073085, 0.3530434432969184, '0.7%'),
#   Text(-0.5988520935902407, -0.03709676539249162, '21.3%'),
#   Text(-0.3409741330271378, -0.4936969116840733, '7.5%'),
#   Text(-0.21623273441728544, -0.5596815206583327, '0.0%'),
#   Text(0.13796423002033142, -0.5839228298627286, '19.1%'),
#   Text(0.39510978404754343, 0.4515398748171678, '50.7%')])

# %%
ETHNICITY = FBI_HATECRIME_FORMATED.iloc[9:13]
ETHNICITY
# Out:
#                          Hatecrime  Total
# 9               Hispanic or Latino    454
# 10          Not Hispanic or Latino  1,284
# 11  Group of Multiple Ethnicities4     81
# 12               Unknown Ethnicity  3,312

# %%
# Labels for the sections of our pie chart
labels = ["Hispanic or Latino", "Not Hispanic or Latino", "Group of Multiple Ethnicities4", "Unknown Ethnicity"]

# The values of each section of the pie chart
sizes = [454, 1284, 81, 3312]

# The colors of each section of the pie chart
colors = ["red", "orange", "lightcoral", "lightskyblue"]

# Tells matplotlib to seperate the "Python" section from the others
explode = (0.1, 0, 0, 0)

# %%
# Creates the pie chart based upon the values above
# Automatically finds the percentages of each part of the pie chart
plt.pie(sizes, explode=explode, labels=labels, colors=colors,
        autopct="%1.1f%%", shadow=True, startangle=140)
# Out:
# ([<matplotlib.patches.Wedge at 0x30e37f28>,
#   <matplotlib.patches.Wedge at 0x30e44908>,
#   <matplotlib.patches.Wedge at 0x30e52278>,
#   <matplotlib.patches.Wedge at 0x30e52ba8>],
#  [Text(-1.0956294023220905, 0.48948566145224226, 'Hispanic or Latino'),
#   Text(-0.8796843821977828, -0.6604206142431545, 'Not Hispanic or Latino'),
#   Text(-0.10002682548926857, -1.0954426658582088, 'Group of Multiple Ethnicities4'),
#   Text(1.0063617420110589, 0.4441126481158435, 'Unknown Ethnicity')],
#  [Text(-0.6391171513545527, 0.28553330251380793, '8.8%'),
#   Text(-0.47982784483515417, -0.3602294259508115, '25.0%'),
#   Text(-0.054560086630510124, -0.5975141813772048, '1.6%'),
#   Text(0.5489245865514866, 0.24224326260864187, '64.5%')])

# %%
AGE = FBI_HATECRIME_FORMATED.iloc[14:]
AGE
# Out:
#                             Hatecrime  Total
# 14  Total known offenders 18 and over  4,062
# 15     Total known offenders under 18    833

# %%
# Labels for the sections of our pie chart
labels = ["Total known offenders 18 and over", "Total known offenders under 18"]

# The values of each section of the pie chart
sizes = [4062, 833]

# The colors of each section of the pie chart
colors = ["red", "blue"]

# Tells matplotlib to seperate the "Python" section from the others
explode = (0.1, 0, 0, 0)

# %%
# Creates the pie chart based upon the values above
# Automatically finds the percentages of each part of the pie chart
plt.pie(sizes, labels=labels, colors=colors,
        autopct="%1.1f%%", shadow=True, startangle=140)
#define bins as 10 to 19, 19-29, 29-39, 39-49, 49-59, 59-69,69-79,79-89
bins_Y = [10, 19, 29, 39, 49, 59, 69, 79, 89]

# %%
groupy_names = ["denarian(10-19)", "vicenarian(20-29)", "tricenarian(30-39)", "quadragenarian(40-49)", "quinquagenarian(50-59)", "sexagenarian(60-69)", "septuagenarian(70-79)", "octogenarian(80-89)"]

# %%
Hatecrime_Year["Age bracket"] = pd.cut(HATECRIME["Age"], bins_Y, labels=groupy_names)
Hatecrime_Year["Age bracket"].value_counts()
# Out:
# C:\Users\molayink\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# vicenarian(20-29)         134
# tricenarian(30-39)        109
# denarian(10-19)            60
# quadragenarian(40-49)      47
# quinquagenarian(50-59)     36
# sexagenarian(60-69)        15
# septuagenarian(70-79)       4
# octogenarian(80-89)         0
# Name: Age bracket, dtype: int64

# %%
Hatecrime_Year.columns
# Out:
# Index(['Precinct', 'Gender', 'Race', 'Age', 'Year', 'Age bracket'], dtype='object')

# %%
# checking just 2017 data from the whole data for precinct and Gender to determine which Gender commited highest hate crime and from which precinct

#male in precinct 14. 61 ,7 and 71  has the highest/commited highest hate crime in descending order

#and female in precinct 120 commited higest hate crime

Hatecrime_Year[Hatecrime_Year.Year==2017].groupby(["Precinct","Gender"]).size().unstack(0).plot(kind="barh", subplots=True, figsize=(30, 40))
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x0000000030B23710>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000000030EEF4A8>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000000030F21908>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x00000000311F0D68>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000000031231208>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000000031263668>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000000031292AC8>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x00000000312C8F60>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x00000000312C8F98>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000000031336828>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000000031367C88>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x00000000313AB128>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x00000000313D9588>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000000003140B9E8>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000000031440E48>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000000003147D2E8>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x00000000314AF710>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x00000000314E4B70>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000000031515FD0>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000000031554470>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x00000000315828D0>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x00000000315B9D30>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x00000000315F51D0>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000000031629630>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000000031659A90>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000000003168FEF0>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x00000000316CB390>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x00000000316FD7F0>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000000031730C50>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000000003176E0F0>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000000003179E550>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x00000000317D19B0>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000000031803E10>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x00000000318422B0>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000000031875710>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x00000000318AAB70>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x00000000318DCFD0>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000000003191A470>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000000003194A8D0>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000000003197ED30>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x00000000319BC1D0>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x00000000319EF630>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000000031A20A90>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000000031A54EF0>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000000031A91390>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000000031AC47F0>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000000031AF6C50>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000000031B360F0>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000000031B65550>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000000031B979B0>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000000031BCCE10>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000000031C0B2B0>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000000031C3B710>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000000031C70B70>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000000031CA2FD0>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000000031CDF470>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000000031D0E8D0>],
#       dtype=object)

# %%
Hatecrime_Year[Hatecrime_Year.Year==2017].groupby(["Precinct","Race"]).size().unstack(0).plot(kind="barh", subplots=True, figsize=(30, 40))
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x0000000035D210B8>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000000035D2FDA0>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000000034413CF8>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000000035E5C4A8>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000000034446908>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000000034477D68>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x00000000344B5208>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x00000000344E96A0>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x00000000344E96D8>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000000003454DF28>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000000003458C3C8>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x00000000345BC828>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x00000000345EEC88>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000000003462F128>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000000034660588>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x00000000346929E8>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x00000000346C6E48>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x00000000347052E8>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000000034734748>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000000034766BA8>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x00000000347A8048>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x00000000347D54A8>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000000034809908>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000000003483DD68>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000000003487D208>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x00000000348AD668>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x00000000348DFAC8>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000000034913F28>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000000003494F3C8>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000000034983828>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x00000000349B5C88>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x00000000349F4128>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000000034A27588>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000000034A589E8>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000000034A8BE48>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000000034AC92E8>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000000034AF9748>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000000034B2CBA8>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000000034B6D048>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000000034B9D4A8>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000000034BCF908>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000000034C05D68>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000000034C42208>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000000034C75668>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000000034CA6AC8>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000000034CD9F28>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000000034D183C8>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000000034D47828>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000000034D7BC88>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000000034DB9128>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000000034DEC588>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000000034E1D9E8>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000000034E51E48>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000000034E902E8>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000000034EC0748>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000000034EF4BA8>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000000034F36048>],
#       dtype=object)

# %%
# getting the Gender /the age bracket commiting highest hate crime for 2017
# ages from 20-29 Male commited highest hate crime in 2017 and 30-39 for female
Hatecrime_Year[Hatecrime_Year.Year==2017].groupby(["Gender","Age bracket"]).size().unstack(0).plot(kind="bar", subplots=True, figsize=(8, 10))
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x0000000035E36860>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000000035B3A940>],
#       dtype=object)

# %%
# white and black men and women commited highest hate crime in 2017
Hatecrime_Year[Hatecrime_Year.Year==2017].groupby(["Gender","Race"]).size().unstack(0).plot(kind="bar", subplots=True, figsize=(8, 10))
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x0000000035A51CC0>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000000035BC49E8>],
#       dtype=object)

# %%
# for 2018 data
# precinct 71  has the highest/commited highest hate crime in descending order

Hatecrime_Year[Hatecrime_Year.Year==2018].groupby(["Precinct","Race"]).size().unstack(0).plot(kind="barh", subplots=True, figsize=(30, 40))
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x0000000036D9FD68>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000000036DB91D0>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000000036E1D358>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000000036E4D7B8>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000000036E80C18>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000000036EBF0B8>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000000037071518>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x00000000370A59B0>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x00000000370A59E8>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000000037115278>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x00000000371466D8>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000000037179B38>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x00000000371AAF98>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000000003733A438>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000000037369898>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000000003739ECF8>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x00000000373DD198>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000000003740E5F8>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000000003743FA58>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000000037474EB8>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x00000000374B2358>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x00000000374E27B8>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000000037515C18>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x00000000375590B8>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000000037586518>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x00000000375BA978>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x00000000375ECDD8>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000000003762B278>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x00000000376596D8>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000000037690B38>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x00000000376C2F98>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x00000000376FF438>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000000037732898>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000000037766CF8>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x00000000377A4198>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x00000000377D55F8>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000000037807A58>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000000003783CEB8>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000000037877358>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x00000000378AB7B8>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x00000000378DCC18>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000000003791E0B8>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000000003794D518>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000000037981978>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x00000000379B2DD8>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x00000000379EF278>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000000037A246D8>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000000037A56B38>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000000037A87F98>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000000037AC6438>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000000037AF8898>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000000037B2ACF8>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000000037B68198>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x00000000358C0160>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000000037B9E198>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000000037BD05F8>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000000037C02A58>],
#       dtype=object)

# %%
#ages from 30-39 followed by 20-29 Male commited highest hate crime in 2018 and 30-39 folllowed by 50-59 for female commited highest hate crime

Hatecrime_Year[Hatecrime_Year.Year==2018].groupby(["Gender","Age bracket"]).size().unstack(0).plot(kind="bar", subplots=True, figsize=(8, 10))
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x000000003BC98B70>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x00000000384CBEB8>],
#       dtype=object)

# %%
# white and black men and women commited highest hate crime in 2018 consistent with 2017 data
Hatecrime_Year[Hatecrime_Year.Year==2018].groupby(["Gender","Race"]).size().unstack(0).plot(kind="bar", subplots=True, figsize=(8, 10))
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x000000003BCE0390>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000000003A5C09B0>],
#       dtype=object)

# %%
import gmaps
import pandas as pd
import numpy as np
# Google developer API key
from config import gkey

# Configure gmaps
gmaps.configure(api_key=gkey)

# %%
HATECRIME
# Out:
#      Precinct  Gender      Race  Age             Age bracket
# 0           6    Male  Hispanic   48   quadragenarian(40-49)
# 1           7    Male     White   29       vicenarian(20-29)
# 2           7    Male     White   29       vicenarian(20-29)
# 3          14    Male  Hispanic   64     sexagenarian(60-69)
# 4          14    Male  Hispanic   64     sexagenarian(60-69)
# 5          14    Male  Hispanic   64     sexagenarian(60-69)
# 6          14    Male  Hispanic   64     sexagenarian(60-69)
# 7          14    Male  Hispanic   64     sexagenarian(60-69)
# 8          14    Male  Hispanic   64     sexagenarian(60-69)
# 9          14    Male  Hispanic   64     sexagenarian(60-69)
# 10         14    Male  Hispanic   64     sexagenarian(60-69)
# 11         14    Male     White   26       vicenarian(20-29)
# 12         14    Male     White   28       vicenarian(20-29)
# 13         19    Male     White   53  quinquagenarian(50-59)
# 14         20    Male  Hispanic   22       vicenarian(20-29)
# 15         22    Male     White   33      tricenarian(30-39)
# 16         52    Male     Black   40   quadragenarian(40-49)
# 17         61    Male     White   25       vicenarian(20-29)
# 18         61    Male     Black   16         denarian(10-19)
# 19         71    Male     Black   11         denarian(10-19)
# 20         71    Male     Black   11         denarian(10-19)
# 21         75    Male     Black   28       vicenarian(20-29)
# 22         79    Male     Black   32      tricenarian(30-39)
# 23         79    Male     Black   32      tricenarian(30-39)
# 24         84    Male     White   36      tricenarian(30-39)
# 25         88    Male  Hispanic   60     sexagenarian(60-69)
# 26         94    Male  Hispanic   32      tricenarian(30-39)
# 27        107    Male  Hispanic   28       vicenarian(20-29)
# 28        113    Male     White   57  quinquagenarian(50-59)
# 29        115    Male  Hispanic   38      tricenarian(30-39)
# ..        ...     ...       ...  ...                     ...
# 375        42  Female     White   15         denarian(10-19)
# 376        61    Male     White   55  quinquagenarian(50-59)
# 377        61    Male     White   55  quinquagenarian(50-59)
# 378        68    Male     White   21       vicenarian(20-29)
# 379        70    Male     White   41   quadragenarian(40-49)
# 380        70    Male     White   34      tricenarian(30-39)
# 381        71  Female     Black   52  quinquagenarian(50-59)
# 382        75    Male     White   46   quadragenarian(40-49)
# 383        75    Male     White   46   quadragenarian(40-49)
# 384        75    Male     White   37      tricenarian(30-39)
# 385        81    Male     Black   26       vicenarian(20-29)
# 386        84    Male     White   48   quadragenarian(40-49)
# 387        88    Male     White   47   quadragenarian(40-49)
# 388        90    Male     Black   16         denarian(10-19)
# 389        94    Male     White   28       vicenarian(20-29)
# 390        94    Male     White   28       vicenarian(20-29)
# 391        94    Male     White   28       vicenarian(20-29)
# 392        94    Male     White   28       vicenarian(20-29)
# 393        94    Male     White   28       vicenarian(20-29)
# 394        94    Male     White   28       vicenarian(20-29)
# 395        94    Male     White   28       vicenarian(20-29)
# 396        94    Male     White   28       vicenarian(20-29)
# 397       101    Male     Black   14         denarian(10-19)
# 398       102    Male     Asian   37      tricenarian(30-39)
# 399       103    Male     White   55  quinquagenarian(50-59)
# 400       107  Female     Asian   23       vicenarian(20-29)
# 401       107    Male     Asian   21       vicenarian(20-29)
# 402       110  Female     White   24       vicenarian(20-29)
# 403       112  Female     White   43   quadragenarian(40-49)
# 404       113    Male     Asian   61     sexagenarian(60-69)
#
# [405 rows x 5 columns]

# %%
# Create a list containing coordinates for new york
coordinates = (40.75, -74.00)

# %%
zipcode = "precincts_zips.csv"

# %%
zipcode = pd.read_csv("../Resources/precincts_zips.csv")
zipcode
# Out:
#     Unnamed: 0  Unnamed: 0.1  precinct_number         Phone  \
# 0            0             0                1  212-334-0611
# 1            1             1                5  212-334-0711
# 2            2             2                6  212-741-4811
# 3            3             3                7  212-477-7311
# 4            4             4                9  212-477-7811
# 5            5             5               10  212-741-8211
# 6            6             6               13  212-477-7411
# 7            7             7               14  212-239-9811
# 8            8             8               17  212-826-3211
# 9            9             9               18  212-767-8400
# 10          10            10               19  212-452-0600
# 11          11            11               20  212-580-6411
# 12          12            12               22  212-570-4820
# 13          13            13               23  212-860-6411
# 14          14            14               24  212-678-1811
# 15          15            15               25  212-860-6511
# 16          16            16               26  212-678-1311
# 17          17            17               28  212-678-1611
# 18          18            18               30  212-690-8811
# 19          19            19               32  212-690-6311
# 20          20            20               33  212-927-3200
# 21          21            21               34  212-927-9711
# 22          22            22               40  718-402-2270
# 23          23            23               41  718-542-4771
# 24          24            24               42  718-402-3887
# 25          25            25               43  718-542-0888
# 26          26            26               44  718-590-5511
# 51                  30 Ralph Avenue, Brooklyn, NY  40.689665 -73.924455
# 52         480 Knickerbocker Avenue, Brooklyn, NY  40.698147 -73.917841
# 53                  301 Gold Street, Brooklyn, NY  40.695548 -73.982917
# 54               298 Classon Avenue, Brooklyn, NY  40.690071 -73.960532
# 55                 211 Union Avenue, Brooklyn, NY  40.706273 -73.950769
# 56              100 Meserole Avenue, Brooklyn, NY  40.726675 -73.953295
# 57     92-24 Rockaway Beach Boulevard, Queens, NY  40.586248 -73.816477
# 58                  16-12 Mott Avenue, Queens, NY  40.602909 -73.749925
# 59                 87-34 118th Street, Queens, NY  40.698721 -73.831567
# 60       168-02 P.O Edward Byrne Ave., Queens, NY  40.667336 -73.807361
# 61                64-2 Catalpa Avenue, Queens, NY  40.704357 -73.893649
# 62                 92-08 222nd Street, Queens, NY  40.726225 -73.735144
# 63                103-53 101st Street, Queens, NY  40.682174 -73.839718
# 64            71-01 Parsons Boulevard, Queens, NY  40.729909 -73.810614
# 65                   5-47 50th Avenue, Queens, NY  40.743083 -73.954672
# 66                 37-05 Union Street, Queens, NY  40.762361 -73.827020
# 67                  94-41 43rd Avenue, Queens, NY  40.745219 -73.870069
# 68                 45-06 215th Street, Queens, NY  40.760244 -73.767781
# 69                68-40 Austin Street, Queens, NY  40.722358 -73.851468
# 70           167-02 Baisley Boulevard, Queens, NY  40.679801 -73.775686
# 71            34-16 Astoria Boulevard, Queens, NY  40.769282 -73.915328
# 72           92-15 Northern Boulevard, Queens, NY  40.756875 -73.875490
# 73         78 Richmond Terrace, Staten Island, NY  40.644628 -74.077423
# 74         970 Richmond Avenue, Staten Island, NY  40.623677 -74.150344
# 75        2320 Hylan Boulevard, Staten Island, NY  40.574118 -74.105506
# 76             116 Main Street, Staten Island, NY  40.511844 -74.250036
#
#     zipcode
# 0     10013
# 1     10013
# 2     10014
# 3     10002
# 4     10003
# 5     10011
# 6     10010
# 7     10001
# 8     10022
# 9     10019
# 10    10065
# 11    10024
# 12    10024
# 13    10029
# 14    10025
# 15    10035
# 16    10027
# 17    10027
# 18    10031
# 19    10030
# 20    10032
# 21    10033
# 22    10454
# 23    10459
# 24    10451
# 25    10473
# 26    10452
# 27    10465
# 28    10457
# 29    10466
# ..      ...
# 47    11231
# 48    11213
# 49    11217
# 50    11216
# 51    11221
# 52    11237
# 53    11201
# 54    11205
# 55    11211
# 56    11222
# 57    11693
# 58    11691
# 59    11418
# 60    11420
# 61    11385
# 62    11428
# 63    11417
# 64    11365
# 65    11101
# 66    11354
# 67    11373
# 68    11361
# 69    11375
# 70    11434
# 71    11103
# 72    11369
# 73    10301
# 74    10314
# 75    10306
# 76    10307
#
# [77 rows x 11 columns]

# %%
ZIPCODE = zipcode[["precinct_number", "lat", "lng", "zipcode"]]
ZIPCODE
# Out:
#     precinct_number        lat        lng  zipcode
# 0                 1  40.720270 -74.007198    10013
# 1                 5  40.716194 -73.997470    10013
# 2                 6  40.734233 -74.005453    10014
# 3                 7  40.716362 -73.983934    10002
# 4                 9  40.644583 -73.975500    10003
# 24        vicenarian(20-29)
# 25        vicenarian(20-29)
# 26        vicenarian(20-29)
# 27        vicenarian(20-29)
# 28       tricenarian(30-39)
# 29        vicenarian(20-29)
# ..                      ...
# 375  quinquagenarian(50-59)
# 376         denarian(10-19)
# 377  quinquagenarian(50-59)
# 378     sexagenarian(60-69)
# 379  quinquagenarian(50-59)
# 380  quinquagenarian(50-59)
# 381         denarian(10-19)
# 382         denarian(10-19)
# 383       vicenarian(20-29)
# 384      tricenarian(30-39)
# 385      tricenarian(30-39)
# 386   quadragenarian(40-49)
# 387  quinquagenarian(50-59)
# 388  quinquagenarian(50-59)
# 389      tricenarian(30-39)
# 390      tricenarian(30-39)
# 391      tricenarian(30-39)
# 392         denarian(10-19)
# 393       vicenarian(20-29)
# 394       vicenarian(20-29)
# 395      tricenarian(30-39)
# 396   quadragenarian(40-49)
# 397      tricenarian(30-39)
# 398         denarian(10-19)
# 399         denarian(10-19)
# 400  quinquagenarian(50-59)
# 401   quadragenarian(40-49)
# 402      tricenarian(30-39)
# 403       vicenarian(20-29)
# 404      tricenarian(30-39)
#
# [405 rows x 8 columns]

# %%
import gmaps
import pandas as pd
import numpy as np
# Google developer API key
from config import gkey

# Configure gmaps
gmaps.configure(api_key=gkey)

# %%
# Create a list containing coordinates
coordinates = (40.75, -74.00)

# %%
fig = gmaps.figure(center=coordinates, zoom_level=12)
locations = HATECRIMZIP[["lat","lng"]]

# %%
# Create heat layer
heatmap_layer = gmaps.heatmap_layer(locations)

#adjust red to make more understandable
heatmap_layer.max_intensity = 50
heatmap_layer.point_radius = 25
fig.add_layer(heatmap_layer)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
Hatecrime_Year[Hatecrime_Year.Year==2017].groupby(["Gender","Age bracket"]).size().unstack(0).plot(kind="bar", subplots=True, figsize=(8, 10))
Hatecrime_Year[Hatecrime_Year.Year==2018].groupby(["Gender","Age bracket"]).size().unstack(0).plot(kind="bar", subplots=True, figsize=(8, 10))
Hatecrime_Year[Hatecrime_Year.Year==2019].groupby(["Gender","Age bracket"]).size().unstack(0).plot(kind="bar", subplots=True, figsize=(8, 10))
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x000000003AEF2828>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000000003AFEE240>],
#       dtype=object)

# %%
Hatecrime_Year[Hatecrime_Year.Year==2017].groupby(["Gender","Race"]).size().unstack(0).plot(kind="bar", subplots=True, figsize=(8, 10))
Hatecrime_Year[Hatecrime_Year.Year==2018].groupby(["Gender","Race"]).size().unstack(0).plot(kind="bar", subplots=True, figsize=(8, 10))
Hatecrime_Year[Hatecrime_Year.Year==2019].groupby(["Gender","Race"]).size().unstack(0).plot(kind="bar", subplots=True, figsize=(8, 10))
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x000000003B607DA0>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000000003B6EEFD0>],
#       dtype=object)

# %%
linestyle='-', marker='o'

# %%
Hatecrime_Year[Hatecrime_Year.Year==2017].groupby(["Gender","Age bracket"]).size().unstack(0).plot(kind="bar", subplots=True, figsize=(8, 10))
Hatecrime_Year[Hatecrime_Year.Year==2018].groupby(["Gender","Age bracket"]).size().unstack(0).plot(kind="bar", subplots=True, figsize=(8, 10))
Hatecrime_Year[Hatecrime_Year.Year==2019].groupby(["Gender","Age bracket"]).size().unstack(0).plot(kind="bar", subplots=True, figsize=(8, 10))

Hatecrime_Year[Hatecrime_Year.Year==2017].groupby(["Gender","Age bracket"]).size().unstack(0).plot(linestyle='-', marker='o', subplots=True, figsize=(8, 10))
Hatecrime_Year[Hatecrime_Year.Year==2018].groupby(["Gender","Age bracket"]).size().unstack(0).plot(linestyle='-', marker='o', subplots=True, figsize=(8, 10))
Hatecrime_Year[Hatecrime_Year.Year==2019].groupby(["Gender","Age bracket"]).size().unstack(0).plot(linestyle='-', marker='o', subplots=True, figsize=(8, 10))
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x000000003E0BD390>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000000003E1683C8>],
#       dtype=object)
